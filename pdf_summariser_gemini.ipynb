# %%
## google
from google import genai
from google.genai import types
import httpx
import re
from dotenv import load_dotenv
import os
from notion_client import Client
from utils import write_to_notion, format_result_to_markdown
import json

load_dotenv()

# Gemini setup
gclient = genai.Client()
# Define the structured output schema
response_schema = {
    "type": "object",
    "properties": {
        "title": {
            "type": "string",
            "description": "The document title"
        },
        "abstract": {
            "type": "string",
            "description": "The document abstract"
        },
        "summary": {
            "type": "string",
            "description": "Most critical information in brief bullet points"
        },
        "extended_summary": {
            "type": "string",
            "description": "Detailed explanation with relevant context"
        }
    },
    "required": ["title", "abstract", "summary", "extended_summary"]
}

# Define the prompt template
prompt = """You are a concise document summariser. Read the PDF provided and
            return a clear, structured summary with key points, important details, and conclusions.
            """
# prompt = """You are a concise document summariser. Read the PDF at the provided URL directly and
#             return a clear, structured summary with key points, important details, and conclusions.
#             Present your output in four sections: 'Title', 'Abstract', 'Summary' and 'Extended Summary'.

#             In 'Title', extract the document title.
#             In 'Abstract', extract the document abstract.
#             In 'Summary', include only the most critical information in brief bullet points.
#             In 'Extended Summary', provide a more detailed explanation with relevant context.
#             Format your response using markdown with appropriate headings and bullet points.
#             """

# gemini_model = "gemini-2.5-flash"
# gemini_model = "gemini-3-pro-preview" # "gemini-2.5-flash"
gemini_model = "gemini-3-flash-preview"

# Notion setup
NOTION_TOKEN = os.getenv("NOTION_TOKEN")
DATABASE_ID = os.getenv("NOTION_DATABASE_ID")
notion = Client(auth=os.environ["NOTION_TOKEN"])

# %%
# put PDF URLs here
urls =[
    # "https://arxiv.org/pdf/2509.25721",
    # "https://arxiv.org/pdf/2512.07796",
    # "https://arxiv.org/pdf/2601.10402"
    # "https://arxiv.org/pdf/2512.18311",
    "https://arxiv.org/pdf/2601.16120"
    # "https://arxiv.org/pdf/2503.13657",
    # "https://cdn.aaai.org/AAAI/2008/AAAI08-227.pdf"
]

# %%
for i, url in enumerate(urls):
    try:
        print(f"Processing document {i+1}/{len(urls)}: {url}")

        # Retrieve and encode the PDF byte
        doc_data = httpx.get(url).content

        # Summarise the document
        response = gclient.models.generate_content(
          model = gemini_model,
          contents=[
              types.Part.from_bytes(
                data=doc_data,
                mime_type='application/pdf',
              ),
              prompt],
              config=types.GenerateContentConfig(
                  response_mime_type="application/json",
                  response_schema=response_schema))

        # Extract title from the response
        result_data = json.loads(response.text)
        title = result_data['title']
        # title = extract_section(response.text, 'Title')
        print(f"Extracted Title: {title}")

        # Write to Notion
        md_content = format_result_to_markdown(result_data)
        result = write_to_notion(
                    title=title,
                    url=url,
                    content=md_content,
                    model_name=gemini_model,
                    notion_token=NOTION_TOKEN,
                    database_id=DATABASE_ID
                    )
        # result = write_to_notion(title, url, response.text, NOTION_TOKEN, DATABASE_ID)
        print(f"Page created successfully: {result['id']}")

    except httpx.HTTPError as e:
        print(f"❌ Error fetching PDF from {url}: {e}")
        continue
    except Exception as e:
        print(f"❌ Error processing {url}: {type(e).__name__}: {e}")
        continue

print(f"\n✅ Processing complete!")
# Out:
# Processing document 1/1: https://arxiv.org/pdf/2601.16120
# Extracted Title: Synthetic Augmentation in Imbalanced Learning: When It Helps, When It Hurts, and How Much to Add
# Page created successfully: 2f4be5eb-a41a-8120-aa08-e8a850b918fa
#
# ✅ Processing complete!

# %%
response.text
# Out:
# '{\n  "title": "Toward Ultra-Long-Horizon Agentic Science: Cognitive Accumulation for Machine Learning Engineering",\n  "abstract": "The advancement of artificial intelligence toward agentic science is currently bottlenecked by the challenge of ultra-long-horizon autonomy, the ability to sustain strategic coherence and iterative correction over experimental cycles spanning days or weeks. While Large Language Models (LLMs) have demonstrated prowess in short-horizon reasoning, they are easily overwhelmed by execution details in the high-dimensional, delayed-feedback environments of real-world research, failing to consolidate sparse feedback into coherent long-term guidance. Here, we present ML-Master 2.0, an autonomous agent that masters ultra-long-horizon machine learning engineering (MLE) which is a representative microcosm of scientific discovery. By reframing context management as a process of cognitive accumulation, our approach introduces Hierarchical Cognitive Caching (HCC), a multi-tiered architecture inspired by computer systems that enables the structural differentiation of experience over time. By dynamically distilling transient execution traces into stable knowledge and cross-task wisdom, HCC allows agents to decouple immediate execution from long-term experimental strategy, effectively overcoming the scaling limits of static context windows. In evaluations on OpenAI’s MLE-Bench under 24-hour budgets, ML-Master 2.0 achieves a state-of-the-art medal rate of 56.44%. Our findings demonstrate that ultra-long-horizon autonomy provides a scalable blueprint for AI capable of autonomous exploration beyond human-precedent complexities.",\n  "summary": "• Introduces ML-Master 2.0, an autonomous agent designed for complex, long-duration machine learning engineering (MLE) tasks.\\n• Proposes Hierarchical Cognitive Caching (HCC), a context management system that separates transient data from long-term wisdom.\\n• Utilizes a three-tier cache architecture: Evolving Experience (L1), Refined Knowledge (L2), and Prior Wisdom (L3).\\n• Achieved a State-of-the-Art (SOTA) medal rate of 56.44% on OpenAI\'s MLE-Bench, outperforming existing proprietary and open-source models.\\n• Successfully manages context windows by distilling 200k+ tokens of raw logs into ~70k tokens of critical insights.",\n  "extended_summary": "This document addresses the \'ultra-long-horizon autonomy\' bottleneck in AI-driven scientific discovery, where agents must maintain strategic focus over hours or days. The researchers use Machine Learning Engineering (MLE) as a testbed for \'agentic science.\' The core innovation is Hierarchical Cognitive Caching (HCC). HCC mimics computer cache hierarchies to prevent \'context saturation.\' The L1 tier (Evolving Experience) acts as working memory for immediate debugging. The L2 tier (Refined Knowledge) stores validated insights from completed experimental phases. The L3 tier (Prior Wisdom) maintains task-agnostic strategies across different competitions. Information is managed via \'Context Migration,\' which includes prefetching (initialization from prior tasks), hits (retrieval policy), and promotion (distilling raw traces into refined knowledge). In performance tests on MLE-Bench using DeepSeek-V3.2-Speciale as a backbone, ML-Master 2.0 achieved a 56.44% medal rate across 75 tasks. It showed consistent improvements in Low, Medium, and High complexity levels, significantly outperforming competitors like FM Agent, MLE-STAR-Pro, and R&D-Agent. Ablation studies confirmed that the removal of any tier—particularly Refined Knowledge (L2)—resulted in a substantial performance drop, proving that structured cognitive accumulation is essential for complex research tasks."\n}'

# %%
result_data
# Out:
# {'title': 'Toward Ultra-Long-Horizon Agentic Science: Cognitive Accumulation for Machine Learning Engineering',
#  'abstract': 'The advancement of artificial intelligence toward agentic science is currently bottlenecked by the challenge of ultra-long-horizon autonomy, the ability to sustain strategic coherence and iterative correction over experimental cycles spanning days or weeks. While Large Language Models (LLMs) have demonstrated prowess in short-horizon reasoning, they are easily overwhelmed by execution details in the high-dimensional, delayed-feedback environments of real-world research, failing to consolidate sparse feedback into coherent long-term guidance. Here, we present ML-Master 2.0, an autonomous agent that masters ultra-long-horizon machine learning engineering (MLE) which is a representative microcosm of scientific discovery. By reframing context management as a process of cognitive accumulation, our approach introduces Hierarchical Cognitive Caching (HCC), a multi-tiered architecture inspired by computer systems that enables the structural differentiation of experience over time. By dynamically distilling transient execution traces into stable knowledge and cross-task wisdom, HCC allows agents to decouple immediate execution from long-term experimental strategy, effectively overcoming the scaling limits of static context windows. In evaluations on OpenAI’s MLE-Bench under 24-hour budgets, ML-Master 2.0 achieves a state-of-the-art medal rate of 56.44%. Our findings demonstrate that ultra-long-horizon autonomy provides a scalable blueprint for AI capable of autonomous exploration beyond human-precedent complexities.',
#  'summary': "• Introduces ML-Master 2.0, an autonomous agent designed for complex, long-duration machine learning engineering (MLE) tasks.\n• Proposes Hierarchical Cognitive Caching (HCC), a context management system that separates transient data from long-term wisdom.\n• Utilizes a three-tier cache architecture: Evolving Experience (L1), Refined Knowledge (L2), and Prior Wisdom (L3).\n• Achieved a State-of-the-Art (SOTA) medal rate of 56.44% on OpenAI's MLE-Bench, outperforming existing proprietary and open-source models.\n• Successfully manages context windows by distilling 200k+ tokens of raw logs into ~70k tokens of critical insights.",
#  'extended_summary': "This document addresses the 'ultra-long-horizon autonomy' bottleneck in AI-driven scientific discovery, where agents must maintain strategic focus over hours or days. The researchers use Machine Learning Engineering (MLE) as a testbed for 'agentic science.' The core innovation is Hierarchical Cognitive Caching (HCC). HCC mimics computer cache hierarchies to prevent 'context saturation.' The L1 tier (Evolving Experience) acts as working memory for immediate debugging. The L2 tier (Refined Knowledge) stores validated insights from completed experimental phases. The L3 tier (Prior Wisdom) maintains task-agnostic strategies across different competitions. Information is managed via 'Context Migration,' which includes prefetching (initialization from prior tasks), hits (retrieval policy), and promotion (distilling raw traces into refined knowledge). In performance tests on MLE-Bench using DeepSeek-V3.2-Speciale as a backbone, ML-Master 2.0 achieved a 56.44% medal rate across 75 tasks. It showed consistent improvements in Low, Medium, and High complexity levels, significantly outperforming competitors like FM Agent, MLE-STAR-Pro, and R&D-Agent. Ablation studies confirmed that the removal of any tier—particularly Refined Knowledge (L2)—resulted in a substantial performance drop, proving that structured cognitive accumulation is essential for complex research tasks."}

# %%
# def format_result_to_markdown(result_data):
#     """
#     Convert structured result data to markdown format with headings.

#     Args:
#         result_data (dict): Dictionary with keys like 'title', 'abstract', 'summary', 'extended_summary'

#     Returns:
#         str: Markdown formatted string with headings and content
#     """
#     markdown_output = []

#     for key, value in result_data.items():
#         # Convert snake_case to Title Case
#         heading = key.replace('_', ' ').title()
#         markdown_output.append(f"## {heading}\n{value}\n")

#     return "".join(markdown_output)

# %%
title
# Out:
# 'Toward Ultra-Long-Horizon Agentic Science: Cognitive Accumulation for Machine Learning Engineering'

# %%
# from datetime import date
# from utils import add_content_to_page
# def write_to_notion(title, url, content, model_name, notion_token, database_id, entry_date = None):
#     """
#     Write JSON output (Summary, Extended Summary) to a Notion database page.

#     Args:
#         title: Document title
#         url: Document URL
#         content: Content to add to the page (will be chunked if needed)
#         model_name: Name of the model used for summarization
#         notion_token: Your Notion API token
#         database_id: The ID of your database
#         entry_date: Date of summarization (defaults to today)
#     """

#     # Initialize the Notion client
#     notion = Client(auth=notion_token)

#     # Set default date to today if not provided
#     if entry_date is None:
#         entry_date = date.today().isoformat()

#     # Create a new page in the database
#     new_page = notion.pages.create(
#         parent={"database_id": database_id},
#         properties={
#             "Title": {
#                 "title": [
#                     {
#                         "text": {
#                             "content": title
#                         }
#                     }
#                 ]
#             },
#             "URL": {
#                 "url": url
#             },
#             "Model Name": {
#                 "rich_text": [
#                     {
#                         "text": {
#                             "content": model_name
#                         }
#                     }
#                 ]
#             },
#             "Date": {
#                 "date": {
#                     "start": entry_date
#                 }
#             }
#         }
#     )

#     # Add content to the page if provided
#     if content:
#         add_content_to_page(notion_token, new_page['id'], content)

#     return new_page

# %%
# result = write_to_notion(
#     title=title,
#     url=url,
#     content=md_content,
#     model_name=gemini_model,
#     notion_token=NOTION_TOKEN,
#     database_id=DATABASE_ID,
#     entry_date=date.today().isoformat())

# %%
print(f"Page created successfully: {result['id']}")
# Out:
# Page created successfully: 2f4be5eb-a41a-81f3-a0ac-dc98e3ddb609
